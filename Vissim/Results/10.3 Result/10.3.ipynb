# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_no_net = pd.read_csv("10.3no.csv", header=1, index_col=0)

# %%
df_no_net
# Out:
#            DELAYAVG(ALL)  SPEEDAVG(ALL)  VEHACT(ALL)  VEHARR(ALL)
# TIMEINT
# 0-120           2.745726      47.700029         46.0           39
# 120-240         8.100536      42.205323         73.0           91
# 240-360        14.372565      36.426310         86.0          111
# 360-480        18.773744      32.457720        109.0          110
# 480-600        23.368030      29.249186        108.0          118
# ...                  ...            ...          ...          ...
# 1800-1920      63.961860      11.501855        280.0          125
# 1920-2040      64.702243      11.314248        284.0          125
# 2040-2160      64.941614      11.457374        282.0          123
# 2160-2280      17.972452      10.867212        285.0           28
# SUM                  NaN            NaN          NaN         2082
#
# [95 rows x 4 columns]

# %%
df_eq_net = pd.read_csv("10.3equal.csv", header=1, index_col=0)

# %%
df_eq_net
# Out:
#            DELAYAVG(ALL)  SPEEDAVG(ALL)  VEHACT(ALL)  VEHARR(ALL)
# TIMEINT
# 0-120          11.072426      40.560367         59.0           26
# 120-240        15.618530      36.518667         79.0           98
# 240-360        14.905675      37.049429         76.0          127
# 360-480        17.832373      34.706214         99.0          110
# 480-600        17.261307      34.303018         88.0          128
# ...                  ...            ...          ...          ...
# 2520-2640      54.223489      15.069048        263.0          150
# 2640-2760      52.843847      15.591281        256.0          158
# 2760-2880      53.296319      15.490712        259.0          153
# 2880-3000      52.657402      15.442731        264.0          155
# SUM                  NaN            NaN          NaN         3478
#
# [127 rows x 4 columns]

# %%
df_scat_net = pd.read_csv("10.3scats.csv", header=1, index_col=0)

# %%
df_scat_net
# Out:
#            DELAYAVG(ALL)  SPEEDAVG(ALL)  VEHACT(ALL)  VEHARR(ALL)
# TIMEINT
# 0-120          11.211338      40.674111         57.0           28
# 120-240        21.396132      32.832514         90.0           85
# 240-360        26.937044      28.288497        109.0          105
# 360-480        30.684737      25.869389        133.0          109
# 480-600        34.740072      23.174968        136.0          114
# ...                  ...            ...          ...          ...
# 840-960        42.738911      19.300268        171.0          120
# 960-1080       45.670280      17.895302        202.0          122
# 1080-1200      50.925658      15.386573        230.0          114
# 1200-1320      17.366414      12.813387        217.0           28
# SUM                  NaN            NaN          NaN         1064
#
# [62 rows x 4 columns]

# %%
df_scoot_net = pd.read_csv("10.3scoot.csv", header=1, index_col=0)

# %%
df_scoot_net
# Out:
#            DELAYAVG(ALL)  SPEEDAVG(ALL)  VEHACT(ALL)  VEHARR(ALL)
# TIMEINT
# 0-120          11.211338      40.674111         57.0           28
# 120-240        21.088204      33.082700         89.0           86
# 240-360        25.107144      29.642288        104.0          109
# 360-480        26.765061      28.080106        123.0          114
# 480-600        30.466636      25.504645        124.0          116
# ...                  ...            ...          ...          ...
# 1080-1200      57.925642      13.495417        239.0          119
# 1200-1320      65.376781      11.598783        248.0          108
# 1320-1440      67.087252      10.683938        263.0          106
# 1440-1560       3.215848      10.088634        262.0            3
# SUM                  NaN            NaN          NaN         1253
#
# [85 rows x 4 columns]

# %%
df_ourdec_net = pd.read_csv("10.3our.csv", header=1, index_col=0)

# %%
df_ourdec_net
# Out:
#            DELAYAVG(ALL)  SPEEDAVG(ALL)  VEHACT(ALL)  VEHARR(ALL)
# TIMEINT
# 0-120           2.508642      46.141608         47.0           38
# 120-240        10.346056      38.771783         81.0           84
# 240-360        16.195960      33.545406         92.0          113
# 360-480        17.962959      31.810006        111.0          114
# 480-600        22.976239      26.344364        116.0          112
# ...                  ...            ...          ...          ...
# 2520-2640      22.340891      12.836341        223.0          115
# 2640-2760      36.553320       8.465577        260.0           70
# 2760-2880      30.144961      10.519784        241.0          109
# 2880-3000      27.833324      11.028808        229.0          101
# SUM                  NaN            NaN          NaN         2528
#
# [122 rows x 4 columns]

# %%
fig = plt.figure()
dl_no_net_Avg = df_no_net["DELAYAVG(ALL)"].groupby("TIMEINT").mean()
dl_eq_net_Avg = df_eq_net["DELAYAVG(ALL)"].groupby("TIMEINT").mean()
dl_scat_net_Avg = df_scat_net["DELAYAVG(ALL)"].groupby("TIMEINT").mean()
dl_scoot_net_Avg = df_scoot_net["DELAYAVG(ALL)"].groupby("TIMEINT").mean()
dl_ourdec_net_Avg = df_ourdec_net["DELAYAVG(ALL)"].groupby("TIMEINT").mean()
plt.plot(dl_no_net_Avg[:len(dl_no_net_Avg)-1], label="No Signaling Avg")
plt.plot(dl_eq_net_Avg[:len(dl_eq_net_Avg)-1], label="Equal Time Signaling Avg")
plt.plot(dl_scat_net_Avg[:len(dl_scat_net_Avg)-1], label="SCAT Avg")
plt.plot(dl_scoot_net_Avg[:len(dl_scoot_net_Avg)-1], label="SCOOT Avg")
plt.plot(dl_ourdec_net_Avg[:len(dl_ourdec_net_Avg)-1], label="Our Decentralized Protocol Avg")
plt.legend()
plt.ylabel("Average Delay (in Seconds)")
plt.xlabel ("Signaling Cycles (in Seconds Interval)")
plt.title("Delay Curve on Single Lane Merge for 1:1 Load")
plt.show()
plt.close(fig)

# %%
fig = plt.figure()
sp_no_net_Avg = df_no_net["SPEEDAVG(ALL)"].groupby("TIMEINT").mean()
sp_eq_net_Avg = df_eq_net["SPEEDAVG(ALL)"].groupby("TIMEINT").mean()
sp_scat_net_Avg = df_scat_net["SPEEDAVG(ALL)"].groupby("TIMEINT").mean()
sp_scoot_net_Avg = df_scoot_net["SPEEDAVG(ALL)"].groupby("TIMEINT").mean()
sp_ourdec_net_Avg = df_ourdec_net["SPEEDAVG(ALL)"].groupby("TIMEINT").mean()
plt.plot(sp_no_net_Avg[:len(sp_no_net_Avg)-1], label="No Signaling Avg")
plt.plot(sp_eq_net_Avg[:len(sp_eq_net_Avg)-1], label="Equal Time Signaling Avg")
plt.plot(sp_scat_net_Avg[:len(sp_scat_net_Avg)-1], label="SCAT Avg")
plt.plot(sp_scoot_net_Avg[:len(sp_scoot_net_Avg)-1], label="SCOOT Avg")
plt.plot(sp_ourdec_net_Avg[:len(sp_ourdec_net_Avg)-1], label="Our Decentralized Protocol Avg")
plt.legend()
plt.ylabel("Average Speed (in Km/hr)")
plt.xlabel ("Signaling Cycles (in Seconds Interval)")
plt.title("Speed Curve on Single Lane Merge for 1:1 Load")
plt.show()
plt.close(fig)

# %%
no_net_Arr = df_no_net["VEHARR(ALL)"].groupby("TIMEINT").sum()
eq_net_Arr = df_eq_net["VEHARR(ALL)"].groupby("TIMEINT").sum()
scat_net_Arr = df_scat_net["VEHARR(ALL)"].groupby("TIMEINT").sum()
scoot_net_Arr = df_scoot_net["VEHARR(ALL)"].groupby("TIMEINT").sum()
ourdec_net_Arr = df_ourdec_net["VEHARR(ALL)"].groupby("TIMEINT").sum()
thpt = []
thpt.append(no_net_Arr[len(no_net_Arr)-1])
thpt.append(eq_net_Arr[len(eq_net_Arr)-1])
thpt.append(scat_net_Arr[len(scat_net_Arr)-1])
thpt.append(scoot_net_Arr[len(scoot_net_Arr)-1])
thpt.append(ourdec_net_Arr[len(ourdec_net_Arr)-1])
stgy = ["No Signal", "Equal Signal", "SCAT", "SCOOT", "Decentralized"]

fig = plt.figure()
plt.bar(stgy, thpt)
plt.xlabel("Control Strategy")
plt.ylabel("Total Throughput (in Number of Cars)")
plt.title("Throughput plot of different strategies for 1:1 load")
plt.show()
plt.close(fig)

# %%
Cap = pd.read_csv("10.3 MAX CAP.csv", header=0, index_col=0)

# %%
sim_end_time = Cap.mean(axis=1)
fig = plt.figure()
Cap_name = [" Decentralized", "No Signal", "Equal Signal",  "SCAT","SCOOT"]
plt.bar(Cap_name, sim_end_time)
plt.xlabel("Control Strategy")
plt.ylabel("Jam Time (in seconds)")
plt.title("Time to hit a jam in different strategies for 1:1 load")
plt.show()
plt.close(fig)
